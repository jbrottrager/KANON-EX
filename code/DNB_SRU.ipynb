# %% [markdown]
# # DNB MARC Record Fetching Workflow
#
# This workflow automates the retrieval, parsing, and saving of bibliographic records from the German National Library (DNB) for a given list of titles and authors. It includes functions to query the DNB SRU interface, handle pagination, parse MARCXML data into structured fields (titles, authors, subjects, languages, publication info, etc.), recursively fetch related records, and incrementally save progress to a CSV file while avoiding duplicates.

# %%
import os
import re
import time
import requests
import pandas as pd
import unicodedata
from bs4 import BeautifulSoup
from lxml import etree
import csv

# %%
titles_df = pd.read_csv('meta-titles_openRefine.csv', sep='\t')

OUTPUT_FILE = "dnb_results.csv"

# %%
titles_df
# Out:
#       ID                         wikiTitle      wikiID  \
# 0      1                      …liner Roma…    noWikiID
# 1      2     Abendstimmung in Scheveningen    noWikiID
# 2      3           Abschied von den Eltern     Q178091
# 3      4       Ach Liebste / laß uns eilen    noWikiID
# 4      5                             Agnes     Q394442
# ..   ...                               ...         ...
# 189  190  Weh dem, der aus der Reihe tanzt  Q116160841
# 190  191                           Woyzeck     Q657215
# 191  192                      Wünschelrute    Q2596645
# 192  193                              Zehn    noWikiID
# 193  194               Ziehende Landschaft    noWikiID
#
#                        title_original author_firstname author_lastname
# 0                        …liner Roma…          Joachim      Ringelnatz
# 1       Abendstimmung in Scheveningen          Irmgard            Keun
# 2             Abschied von den Eltern            Peter           Weiss
# 3         Ach Liebste / laß uns eilen           Martin           Opitz
# 4                               Agnes            Peter           Stamm
# ..                                ...              ...             ...
# 189  Weh dem, der aus der Reihe tanzt           Ludwig           Harig
# 190                           Woyzeck            Georg         Büchner
# 191                      Wünschelrute           Joseph     Eichendorff
# 192                              Zehn           Franka         Potente
# 193               Ziehende Landschaft            Hilde          Domin
#
# [194 rows x 6 columns]

# %% [markdown]
# ## Functions

# %% [markdown]
# ### SAVE & LOAD PROGRESS
#
# #### `save_progress(df, output_file=OUTPUT_FILE)`
# Saves progress to a CSV file, merging with existing data and avoiding duplicate records.
#
# #### `load_done_ids(output_file=OUTPUT_FILE)`
# Loads a list of already processed IDs from the saved CSV file to skip completed titles.

# %%
def save_progress(df, output_file=OUTPUT_FILE):
    """
    Append or update progress in the output CSV file.
    Ensures records are unique by 'idn' (or full row if not available).
    """
    if "ID" not in df.columns:
        print("Warning: no 'ID' column in dataframe before saving.")
    
    # Combine with existing file if present
    if os.path.exists(output_file):
        existing = pd.read_csv(output_file, sep=";", quotechar='"', dtype=str)
        df = pd.concat([existing, df], ignore_index=True)
        if "idn" in df.columns:
            df = df.drop_duplicates(subset=["idn"], keep="last")
        else:
            df = df.drop_duplicates()

    # Ensure all values are stored as strings to avoid quoting issues
    df = df.astype(str)

    # Save file with all fields quoted and UTF-8 BOM for Excel compatibility
    df.to_csv(
        output_file,
        index=False,
        sep=";",
        quotechar='"',
        quoting=csv.QUOTE_ALL,
        encoding="utf-8-sig",
    )
    print(f"Progress saved: {len(df)} total records in {output_file}")


def load_done_ids(output_file=OUTPUT_FILE):
    """
    Load already processed IDs from the saved CSV file.
    Returns a set of IDs to skip in the next run.
    """
    if not os.path.exists(output_file):
        return set()
    df = pd.read_csv(output_file, sep=";", quotechar='"', dtype=str)
    if "ID" in df.columns:
        return set(df["ID"].dropna().unique())
    elif "idn" in df.columns:
        print("Warning: no 'ID' column in saved file; using 'idn' instead.")
        return set(df["idn"].dropna().unique())
    else:
        print("Warning: neither 'ID' nor 'idn' found in saved file.")
        return set()

# %% [markdown]
# ### DNB SRU FUNCTIONS
#
# #### `dnb_sru_all(title, author=None, batch_size=50, sleep_sec=2, verbose=True)`
# Queries the DNB SRU interface for bibliographic records by title and optional author, handling pagination and retries.
#
# #### `dnb_sru_all_by_idn(idn, sleep_sec=0.2)`
# Fetches a single bibliographic record from the DNB using its unique IDN identifier.

# %%
def dnb_sru_all(title, author=None, batch_size=50, sleep_sec=2, verbose=True):
    """
    Query the DNB SRU interface for a given title (and optional author).
    Tries both (title + author) and title-only queries.
    Fetches results in batches and follows SRU pagination.
    """
    base_url = "https://services.dnb.de/sru/dnb"
    title_clean = title.replace("'", "\\'")
    all_records = []

    # Build queries: title+author (preferred) and title-only (fallback)
    queries = []
    if author:
        queries.append(f'(dc.title all "{title_clean}") and (dc.creator all "{author}")')    
    queries.append(f'(dc.title all "{title_clean}")')  # fallback

    # Loop through both queries until results found
    for q in queries:
        start = 1
        total_found = 0
        if verbose:
            print(f"Trying query: {q}")

        while True:
            params = {
                "version": "1.1",
                "operation": "searchRetrieve",
                "recordSchema": "MARC21-xml",
                "maximumRecords": str(batch_size),
                "startRecord": str(start),
                "query": q
            }

            # Query DNB API and handle potential errors
            try:
                r = requests.get(base_url, params=params, timeout=30)
                r.raise_for_status()
            except requests.exceptions.RequestException as e:
                print(f"Request failed at start={start}: {e}")
                break

            xml = BeautifulSoup(r.content, "xml")
            records = xml.find_all("record", {"type": "Bibliographic"})
            num = len(records)

            if verbose:
                print(f" → Retrieved {num} records (start={start})")

            if num == 0:
                break  # no more results

            all_records.extend(records)
            total_found += num

            # Handle pagination if more results available
            next_pos_tag = xml.find("nextRecordPosition")
            if next_pos_tag and next_pos_tag.text:
                start = int(next_pos_tag.text)
                time.sleep(sleep_sec)
            else:
                break

        # Stop after first query that returns results
        if total_found > 0:
            if verbose:
                print(f"Found {total_found} records for query: {q}")
            break
        else:
            if verbose:
                print(f"No results for query: {q}")

    return all_records


def dnb_sru_all_by_idn(idn, sleep_sec=0.2):
    """
    Fetch a specific record (and possible variants) from DNB by its IDN.
    Used to retrieve related records recursively.
    """
    base_url = "https://services.dnb.de/sru/dnb"
    query = f"idn={idn}"
    params = {
        "version": "1.1",
        "operation": "searchRetrieve",
        "recordSchema": "MARC21-xml",
        "maximumRecords": "10",
        "query": query
    }
    try:
        r = requests.get(base_url, params=params, timeout=30)
        r.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"IDN fetch failed for {idn}: {e}")
        return []
    xml = BeautifulSoup(r.content, "xml")
    records = xml.find_all("record", {"type": "Bibliographic"})
    time.sleep(sleep_sec)
    return records

# %% [markdown]
# ### PARSE MARC XML
#
# #### `parse_record(record)`
# Parses MARCXML data into a structured dictionary, extracting fields like title, author, subjects, languages, and publication info.

# %%
def parse_record(record):
    """
    Parse one MARCXML record and extract key bibliographic fields.
    Includes both standard and additional (subject, genre, etc.) fields.
    """
    record_str = unicodedata.normalize("NFC", str(record))
    ns = {"marc": "http://www.loc.gov/MARC21/slim"}
    try:
        xml = etree.fromstring(record_str.encode("utf-8"))
    except Exception:
        return {}

    # --- Helper functions for MARC structure ---
    def get_control(tag):
        nodes = xml.xpath(f"marc:controlfield[@tag='{tag}']", namespaces=ns)
        return nodes[0].text if nodes else None

    def get_datafield(tag, code=None):
        nodes = xml.xpath(f"marc:datafield[@tag='{tag}']", namespaces=ns)
        texts = []
        for node in nodes:
            if code:
                subs = node.xpath(f"marc:subfield[@code='{code}']", namespaces=ns)
                texts.extend([s.text.strip() for s in subs if s.text])
            else:
                texts.append(" || ".join([s.text.strip() for s in node.xpath("marc:subfield", namespaces=ns) if s.text]))
        return " || ".join(texts) if texts else None

    def get_fields(tag_list):
        """Combine multiple MARC tags into one string."""
        combined = []
        for t in tag_list:
            val = get_datafield(t)
            if val:
                combined.append(val)
        return " || ".join(combined) if combined else None

    # --- Control fields ---
    idn = get_control("001")
    field_008 = get_control("008")

    # --- Title and variant titles ---
    title = get_datafield("245", "a") or get_datafield("240", "a") or get_datafield("130", "a")
    standardised_title = get_datafield("240", "a") or get_datafield("130", "a") or title
    alternative_titles = get_datafield("246")

    # --- Author and identifiers ---
    author = get_datafield("100", "a") or get_datafield("700", "a")
    rela = get_datafield("100", "e")
    gnd = get_datafield("100", "0") or get_datafield("700", "0")

    # --- Publication info ---
    pub_year = get_datafield("264", "c") or (field_008[7:11] if field_008 else None)

    # --- Links, notes, and series ---
    links = get_datafield("856", "u")
    series = get_fields(["490", "830"])
    notes = get_fields([f"{i:03}" for i in range(500, 600)])
    related_items = get_fields(["776", "787"])

    # --- Additional MARC fields ---
    language_codes = get_datafield("041")
    subject_chron = get_datafield("648")    # chronological subject
    subject_topical = get_datafield("650")  # topical subject
    genre_form = get_datafield("655")       # genre/form
    publication_info = get_fields(["264"])  # full publication statement

    return {
        "idn": idn,
        "title": title,
        "standardised_title": standardised_title,
        "alternative_titles": alternative_titles,
        "author": author,
        "rela": rela,
        "gnd": gnd,
        "pub_year": pub_year,
        "links": links,
        "series": series,
        "notes": notes,
        "related_items": related_items,
        "language_codes": language_codes,
        "subject_chron": subject_chron,
        "subject_topical": subject_topical,
        "genre_form": genre_form,
        "publication_info": publication_info,
        "control_008": field_008
    }

# %% [markdown]
# ### RECURSIVE FETCHING
#
# #### `extract_idns_from_related(text)`
# Extracts IDN identifiers from related-item fields in MARCXML using regular expressions.
#
# #### `fetch_related_records(record_ids, seen=None)`
# Retrieves and parses related DNB records recursively, avoiding duplicates through a `seen` set.

# %%
def extract_idns_from_related(text):
    """Extract numeric DNB IDNs from a text string using regex."""
    if not text:
        return []
    return re.findall(r'\b\d{8,}\b', text)


def fetch_related_records(record_ids, seen=None):
    """
    Recursively fetch and parse records linked to the given IDNs.
    Uses a 'seen' set to avoid infinite loops.
    """
    if seen is None:
        seen = set()
    all_parsed = []
    for rid in record_ids:
        if rid in seen:
            continue
        seen.add(rid)
        recs = dnb_sru_all_by_idn(rid)
        for r in recs:
            parsed = parse_record(r)
            if parsed:
                all_parsed.append(parsed)
                related_ids = extract_idns_from_related(parsed.get("related_items"))
                # Recursively fetch related records
                all_parsed.extend(fetch_related_records(related_ids, seen))
    return all_parsed

# %% [markdown]
# ### MAIN SCRIPT
#
# #### `main(titles_df)`
# Iterates through the input dataframe of titles, fetches main and related DNB records for each, and saves results incrementally.

# %%
def main(titles_df):
    """
    Main driver function:
      - Loads already completed IDs
      - Iterates over all titles in the dataframe
      - Fetches main and related DNB records
      - Saves progress incrementally
    """
    done_ids = load_done_ids()
    print(f"Already done: {len(done_ids)} titles → {sorted(done_ids)}")

    try:
        for _, row in titles_df.iterrows():
            ID = row["ID"]
            if ID in done_ids:
                print(f"Skipping already done: {row['title_original']}")
                continue

            title = row["title_original"]

            # --- Clean and combine author name ---
            first = str(row.get("author_firstname", "") or "").strip()
            last = str(row.get("author_lastname", "") or "").strip()
            author = f"{first} {last}".strip() or None

            print(f"\nFetching main records for: {title}" + (f" ({author})" if author else ""))

            # --- Fetch main records ---
            main_records = dnb_sru_all(title, author=author, batch_size=25) if author else dnb_sru_all(title, batch_size=25)
            parsed = [parse_record(r) for r in main_records if r]
            print(f"Retrieved {len(parsed)} main records for {title}")

            for p in parsed:
                p.update(row.to_dict())  # attach metadata from input CSV

            # --- Fetch related records ---
            related_idns = list(set(idn for p in parsed for idn in extract_idns_from_related(p.get("related_items"))))
            print(f"Fetching {len(related_idns)} related records for {title}")

            related_parsed = fetch_related_records(related_idns)
            for rp in related_parsed:
                rp.update(row.to_dict())
            print(f"Retrieved {len(related_parsed)} related records for {title}")

            # --- Save progress after each title ---
            df_title = pd.DataFrame(parsed + related_parsed)
            if not df_title.empty:
                save_progress(df_title)
            else:
                print(f"No records found for {title}")

    except KeyboardInterrupt:
        print("\nManual stop detected — progress saved.")
    except Exception as e:
        print(f"\nError occurred: {e}")
    finally:
        print("Script finished safely.")

# %% [markdown]
# ### Execution

# %%
main(titles_df)
# Out:
# Already done: 0 titles → []
#
# Fetching main records for: …liner Roma… (Joachim Ringelnatz)
# Trying query: (dc.title all "…liner Roma…") and (dc.creator all "Joachim Ringelnatz")
#  → Retrieved 13 records (start=1)
# Found 13 records for query: (dc.title all "…liner Roma…") and (dc.creator all "Joachim Ringelnatz")
# Retrieved 13 main records for …liner Roma…
# Fetching 5 related records for …liner Roma…
# Retrieved 2 related records for …liner Roma…
# Progress saved: 15 total records in 251014_dnb_results.csv
#
# Fetching main records for: Abendstimmung in Scheveningen (Irmgard Keun)
# Trying query: (dc.title all "Abendstimmung in Scheveningen") and (dc.creator all "Irmgard Keun")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Abendstimmung in Scheveningen") and (dc.creator all "Irmgard Keun")
# Trying query: (dc.title all "Abendstimmung in Scheveningen")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Abendstimmung in Scheveningen")
# Retrieved 0 main records for Abendstimmung in Scheveningen
# Fetching 0 related records for Abendstimmung in Scheveningen
# Retrieved 0 related records for Abendstimmung in Scheveningen
# No records found for Abendstimmung in Scheveningen
#
# Fetching main records for: Abschied von den Eltern (Peter Weiss)
# Trying query: (dc.title all "Abschied von den Eltern") and (dc.creator all "Peter Weiss")
#  → Retrieved 25 records (start=1)
#  → Retrieved 13 records (start=26)
# Found 38 records for query: (dc.title all "Abschied von den Eltern") and (dc.creator all "Peter Weiss")
# Retrieved 38 main records for Abschied von den Eltern
# Fetching 6 related records for Abschied von den Eltern
# Retrieved 0 related records for Abschied von den Eltern
# Progress saved: 51 total records in 251014_dnb_results.csv
#
# Fetching main records for: Ach Liebste / laß uns eilen (Martin Opitz)
# Trying query: (dc.title all "Ach Liebste / laß uns eilen") and (dc.creator all "Martin Opitz")
#  → Retrieved 1 records (start=1)
# Found 1 records for query: (dc.title all "Ach Liebste / laß uns eilen") and (dc.creator all "Martin Opitz")
# Retrieved 1 main records for Ach Liebste / laß uns eilen
# Fetching 0 related records for Ach Liebste / laß uns eilen
# Retrieved 0 related records for Ach Liebste / laß uns eilen
# Progress saved: 52 total records in 251014_dnb_results.csv
#
# Fetching main records for: Agnes (Peter Stamm)
# Trying query: (dc.title all "Agnes") and (dc.creator all "Peter Stamm")
#  → Retrieved 25 records (start=1)
#  → Retrieved 7 records (start=26)
# Found 32 records for query: (dc.title all "Agnes") and (dc.creator all "Peter Stamm")
# Retrieved 32 main records for Agnes
# Fetching 3 related records for Agnes
# Retrieved 2 related records for Agnes
# Progress saved: 85 total records in 251014_dnb_results.csv
#
# Fetching main records for: An die Nachgeborenen (Bertolt Brecht)
# Trying query: (dc.title all "An die Nachgeborenen") and (dc.creator all "Bertolt Brecht")
#  → Retrieved 7 records (start=1)
# Found 7 records for query: (dc.title all "An die Nachgeborenen") and (dc.creator all "Bertolt Brecht")
# Retrieved 7 main records for An die Nachgeborenen
# Fetching 0 related records for An die Nachgeborenen
# Retrieved 0 related records for An die Nachgeborenen
# Progress saved: 92 total records in 251014_dnb_results.csv
#
# Fetching main records for: Anekdote aus dem letzten preußischen Kriege (Heinrich Kleist)
# Trying query: (dc.title all "Anekdote aus dem letzten preußischen Kriege") and (dc.creator all "Heinrich Kleist")
#  → Retrieved 3 records (start=1)
# Found 3 records for query: (dc.title all "Anekdote aus dem letzten preußischen Kriege") and (dc.creator all "Heinrich Kleist")
# Retrieved 3 main records for Anekdote aus dem letzten preußischen Kriege
# Fetching 0 related records for Anekdote aus dem letzten preußischen Kriege
# Retrieved 0 related records for Anekdote aus dem letzten preußischen Kriege
# Progress saved: 95 total records in 251014_dnb_results.csv
#
# Fetching main records for: Ansichten eines Clowns (Heinrich Böll)
# Trying query: (dc.title all "Ansichten eines Clowns") and (dc.creator all "Heinrich Böll")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 18 records (start=151)
# Found 168 records for query: (dc.title all "Ansichten eines Clowns") and (dc.creator all "Heinrich Böll")
# Retrieved 168 main records for Ansichten eines Clowns
# Fetching 7 related records for Ansichten eines Clowns
# Retrieved 2 related records for Ansichten eines Clowns
# Progress saved: 263 total records in 251014_dnb_results.csv
#
# Fetching main records for: Antigone (Anouilh Jean)
# Trying query: (dc.title all "Antigone") and (dc.creator all "Anouilh Jean")
#  → Retrieved 25 records (start=1)
#  → Retrieved 5 records (start=26)
# Found 30 records for query: (dc.title all "Antigone") and (dc.creator all "Anouilh Jean")
# Retrieved 30 main records for Antigone
# Fetching 6 related records for Antigone
# Retrieved 4 related records for Antigone
# Progress saved: 293 total records in 251014_dnb_results.csv
#
# Fetching main records for: Antigone (Sophokles)
# Trying query: (dc.title all "Antigone") and (dc.creator all "Sophokles")
#  → Retrieved 19 records (start=1)
# Found 19 records for query: (dc.title all "Antigone") and (dc.creator all "Sophokles")
# Retrieved 19 main records for Antigone
# Fetching 8 related records for Antigone
# Retrieved 5 related records for Antigone
# Progress saved: 313 total records in 251014_dnb_results.csv
#
# Fetching main records for: Appell an den Geist (Erich Mühsam)
# Trying query: (dc.title all "Appell an den Geist") and (dc.creator all "Erich Mühsam")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Appell an den Geist") and (dc.creator all "Erich Mühsam")
# Trying query: (dc.title all "Appell an den Geist")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Appell an den Geist")
# Retrieved 0 main records for Appell an den Geist
# Fetching 0 related records for Appell an den Geist
# Retrieved 0 related records for Appell an den Geist
# No records found for Appell an den Geist
#
# Fetching main records for: Aus dem Leben eines Taugenichts (Joseph Eichendorff)
# Trying query: (dc.title all "Aus dem Leben eines Taugenichts") and (dc.creator all "Joseph Eichendorff")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 25 records (start=301)
#  → Retrieved 25 records (start=326)
#  → Retrieved 25 records (start=351)
#  → Retrieved 25 records (start=376)
#  → Retrieved 25 records (start=401)
#  → Retrieved 21 records (start=426)
# Found 446 records for query: (dc.title all "Aus dem Leben eines Taugenichts") and (dc.creator all "Joseph Eichendorff")
# Retrieved 446 main records for Aus dem Leben eines Taugenichts
# Fetching 109 related records for Aus dem Leben eines Taugenichts
# Retrieved 101 related records for Aus dem Leben eines Taugenichts
# Progress saved: 761 total records in 251014_dnb_results.csv
#
# Fetching main records for: Bahnwärter Thiel (Gerhart Hauptmann)
# Trying query: (dc.title all "Bahnwärter Thiel") and (dc.creator all "Gerhart Hauptmann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 24 records (start=126)
# Found 149 records for query: (dc.title all "Bahnwärter Thiel") and (dc.creator all "Gerhart Hauptmann")
# Retrieved 149 main records for Bahnwärter Thiel
# Fetching 60 related records for Bahnwärter Thiel
# Retrieved 35 related records for Bahnwärter Thiel
# Progress saved: 912 total records in 251014_dnb_results.csv
#
# Fetching main records for: Bei den weißen Stiefmütterchen (Sarah Kirsch)
# Trying query: (dc.title all "Bei den weißen Stiefmütterchen") and (dc.creator all "Sarah Kirsch")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Bei den weißen Stiefmütterchen") and (dc.creator all "Sarah Kirsch")
# Trying query: (dc.title all "Bei den weißen Stiefmütterchen")
#  → Retrieved 2 records (start=1)
# Found 2 records for query: (dc.title all "Bei den weißen Stiefmütterchen")
# Retrieved 2 main records for Bei den weißen Stiefmütterchen
# Fetching 1 related records for Bei den weißen Stiefmütterchen
# Retrieved 0 related records for Bei den weißen Stiefmütterchen
# Progress saved: 914 total records in 251014_dnb_results.csv
#
# Fetching main records for: Bekenntnisse des Hochstaplers Felix Krull (Thomas Mann)
# Trying query: (dc.title all "Bekenntnisse des Hochstaplers Felix Krull") and (dc.creator all "Thomas Mann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 12 records (start=226)
# Found 237 records for query: (dc.title all "Bekenntnisse des Hochstaplers Felix Krull") and (dc.creator all "Thomas Mann")
# Retrieved 237 main records for Bekenntnisse des Hochstaplers Felix Krull
# Fetching 40 related records for Bekenntnisse des Hochstaplers Felix Krull
# Retrieved 17 related records for Bekenntnisse des Hochstaplers Felix Krull
# Progress saved: 1151 total records in 251014_dnb_results.csv
#
# Fetching main records for: Berlin Alexanderplatz (Alfred Döblin)
# Trying query: (dc.title all "Berlin Alexanderplatz") and (dc.creator all "Alfred Döblin")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 17 records (start=151)
# Found 167 records for query: (dc.title all "Berlin Alexanderplatz") and (dc.creator all "Alfred Döblin")
# Retrieved 167 main records for Berlin Alexanderplatz
# Fetching 23 related records for Berlin Alexanderplatz
# Retrieved 19 related records for Berlin Alexanderplatz
# Progress saved: 1319 total records in 251014_dnb_results.csv
#
# Fetching main records for: Blüthenstaub (Friedrich Hardenberg)
# Trying query: (dc.title all "Blüthenstaub") and (dc.creator all "Friedrich Hardenberg")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Blüthenstaub") and (dc.creator all "Friedrich Hardenberg")
# Trying query: (dc.title all "Blüthenstaub")
#  → Retrieved 18 records (start=1)
# Found 18 records for query: (dc.title all "Blüthenstaub")
# Retrieved 18 main records for Blüthenstaub
# Fetching 2 related records for Blüthenstaub
# Retrieved 0 related records for Blüthenstaub
# Progress saved: 1337 total records in 251014_dnb_results.csv
#
# Fetching main records for: Brief an den Prinzen friedrich Christian II (Friedrich Schiller)
# Trying query: (dc.title all "Brief an den Prinzen friedrich Christian II") and (dc.creator all "Friedrich Schiller")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Brief an den Prinzen friedrich Christian II") and (dc.creator all "Friedrich Schiller")
# Trying query: (dc.title all "Brief an den Prinzen friedrich Christian II")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Brief an den Prinzen friedrich Christian II")
# Retrieved 0 main records for Brief an den Prinzen friedrich Christian II
# Fetching 0 related records for Brief an den Prinzen friedrich Christian II
# Retrieved 0 related records for Brief an den Prinzen friedrich Christian II
# No records found for Brief an den Prinzen friedrich Christian II
#
# Fetching main records for: Brief des Lord Chandos (Hugo Hofmannsthal)
# Trying query: (dc.title all "Brief des Lord Chandos") and (dc.creator all "Hugo Hofmannsthal")
#  → Retrieved 20 records (start=1)
# Found 20 records for query: (dc.title all "Brief des Lord Chandos") and (dc.creator all "Hugo Hofmannsthal")
# Retrieved 20 main records for Brief des Lord Chandos
# Fetching 5 related records for Brief des Lord Chandos
# Retrieved 4 related records for Brief des Lord Chandos
# Progress saved: 1357 total records in 251014_dnb_results.csv
#
# Fetching main records for: Bruder Hitler (Thomas Mann)
# Trying query: (dc.title all "Bruder Hitler") and (dc.creator all "Thomas Mann")
#  → Retrieved 1 records (start=1)
# Found 1 records for query: (dc.title all "Bruder Hitler") and (dc.creator all "Thomas Mann")
# Retrieved 1 main records for Bruder Hitler
# Fetching 0 related records for Bruder Hitler
# Retrieved 0 related records for Bruder Hitler
# Progress saved: 1358 total records in 251014_dnb_results.csv
#
# Fetching main records for: Buddenbrooks (Thomas Mann)
# Trying query: (dc.title all "Buddenbrooks") and (dc.creator all "Thomas Mann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 25 records (start=301)
#  → Retrieved 25 records (start=326)
#  → Retrieved 25 records (start=351)
#  → Retrieved 4 records (start=376)
# Found 379 records for query: (dc.title all "Buddenbrooks") and (dc.creator all "Thomas Mann")
# Retrieved 379 main records for Buddenbrooks
# Fetching 67 related records for Buddenbrooks
# Retrieved 32 related records for Buddenbrooks
# Progress saved: 1737 total records in 251014_dnb_results.csv
#
# Fetching main records for: Corpus Delicti (Juli Zeh)
# Trying query: (dc.title all "Corpus Delicti") and (dc.creator all "Juli Zeh")
#  → Retrieved 25 records (start=1)
#  → Retrieved 13 records (start=26)
# Found 38 records for query: (dc.title all "Corpus Delicti") and (dc.creator all "Juli Zeh")
# Retrieved 38 main records for Corpus Delicti
# Fetching 15 related records for Corpus Delicti
# Retrieved 7 related records for Corpus Delicti
# Progress saved: 1776 total records in 251014_dnb_results.csv
#
# Fetching main records for: Dantons Tod (Georg Büchner)
# Trying query: (dc.title all "Dantons Tod") and (dc.creator all "Georg Büchner")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 18 records (start=201)
# Found 218 records for query: (dc.title all "Dantons Tod") and (dc.creator all "Georg Büchner")
# Retrieved 218 main records for Dantons Tod
# Fetching 49 related records for Dantons Tod
# Retrieved 32 related records for Dantons Tod
# Progress saved: 1994 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Erdbeben in Chili (Heinrich Kleist)
# Trying query: (dc.title all "Das Erdbeben in Chili") and (dc.creator all "Heinrich Kleist")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 23 records (start=101)
# Found 123 records for query: (dc.title all "Das Erdbeben in Chili") and (dc.creator all "Heinrich Kleist")
# Retrieved 123 main records for Das Erdbeben in Chili
# Fetching 28 related records for Das Erdbeben in Chili
# Retrieved 27 related records for Das Erdbeben in Chili
# Progress saved: 2120 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Feuer (Henri Barbusse)
# Trying query: (dc.title all "Das Feuer") and (dc.creator all "Henri Barbusse")
#  → Retrieved 25 records (start=1)
#  → Retrieved 6 records (start=26)
# Found 31 records for query: (dc.title all "Das Feuer") and (dc.creator all "Henri Barbusse")
# Retrieved 31 main records for Das Feuer
# Fetching 7 related records for Das Feuer
# Retrieved 7 related records for Das Feuer
# Progress saved: 2151 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Göttliche (Johann Wolfgang Goethe)
# Trying query: (dc.title all "Das Göttliche") and (dc.creator all "Johann Wolfgang Goethe")
#  → Retrieved 5 records (start=1)
# Found 5 records for query: (dc.title all "Das Göttliche") and (dc.creator all "Johann Wolfgang Goethe")
# Retrieved 5 main records for Das Göttliche
# Fetching 0 related records for Das Göttliche
# Retrieved 0 related records for Das Göttliche
# Progress saved: 2156 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Haus in der Dorotheenstraße (Hartmut Lange)
# Trying query: (dc.title all "Das Haus in der Dorotheenstraße") and (dc.creator all "Hartmut Lange")
#  → Retrieved 4 records (start=1)
# Found 4 records for query: (dc.title all "Das Haus in der Dorotheenstraße") and (dc.creator all "Hartmut Lange")
# Retrieved 4 main records for Das Haus in der Dorotheenstraße
# Fetching 1 related records for Das Haus in der Dorotheenstraße
# Retrieved 0 related records for Das Haus in der Dorotheenstraße
# Progress saved: 2160 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das kunstseidene Mädchen (Irmgard Keun)
# Trying query: (dc.title all "Das kunstseidene Mädchen") and (dc.creator all "Irmgard Keun")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 17 records (start=51)
# Found 67 records for query: (dc.title all "Das kunstseidene Mädchen") and (dc.creator all "Irmgard Keun")
# Retrieved 67 main records for Das kunstseidene Mädchen
# Fetching 29 related records for Das kunstseidene Mädchen
# Retrieved 12 related records for Das kunstseidene Mädchen
# Progress saved: 2228 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Marmorbild (Joseph Eichendorff)
# Trying query: (dc.title all "Das Marmorbild") and (dc.creator all "Joseph Eichendorff")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 11 records (start=101)
# Found 111 records for query: (dc.title all "Das Marmorbild") and (dc.creator all "Joseph Eichendorff")
# Retrieved 111 main records for Das Marmorbild
# Fetching 30 related records for Das Marmorbild
# Retrieved 22 related records for Das Marmorbild
# Progress saved: 2334 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Muschelessen  (Birgit Vanderbeke)
# Trying query: (dc.title all "Das Muschelessen ") and (dc.creator all "Birgit Vanderbeke")
#  → Retrieved 21 records (start=1)
# Found 21 records for query: (dc.title all "Das Muschelessen ") and (dc.creator all "Birgit Vanderbeke")
# Retrieved 21 main records for Das Muschelessen
# Fetching 3 related records for Das Muschelessen
# Retrieved 2 related records for Das Muschelessen
# Progress saved: 2355 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Parfum (Patrick Süskind)
# Trying query: (dc.title all "Das Parfum") and (dc.creator all "Patrick Süskind")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 4 records (start=151)
# Found 154 records for query: (dc.title all "Das Parfum") and (dc.creator all "Patrick Süskind")
# Retrieved 154 main records for Das Parfum
# Fetching 13 related records for Das Parfum
# Retrieved 5 related records for Das Parfum
# Progress saved: 2511 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Schloss  (Franz Kafka)
# Trying query: (dc.title all "Das Schloss ") and (dc.creator all "Franz Kafka")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 25 records (start=301)
#  → Retrieved 25 records (start=326)
#  → Retrieved 25 records (start=351)
#  → Retrieved 9 records (start=376)
# Found 384 records for query: (dc.title all "Das Schloss ") and (dc.creator all "Franz Kafka")
# Retrieved 384 main records for Das Schloss
# Fetching 138 related records for Das Schloss
# Retrieved 46 related records for Das Schloss
# Progress saved: 2895 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Schloss Dürande (Joseph Eichendorff)
# Trying query: (dc.title all "Das Schloss Dürande") and (dc.creator all "Joseph Eichendorff")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 3 records (start=76)
# Found 78 records for query: (dc.title all "Das Schloss Dürande") and (dc.creator all "Joseph Eichendorff")
# Retrieved 78 main records for Das Schloss Dürande
# Fetching 14 related records for Das Schloss Dürande
# Retrieved 12 related records for Das Schloss Dürande
# Progress saved: 2944 total records in 251014_dnb_results.csv
#
# Fetching main records for: Das Urteil (Franz Kafka)
# Trying query: (dc.title all "Das Urteil") and (dc.creator all "Franz Kafka")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 8 records (start=176)
# Found 183 records for query: (dc.title all "Das Urteil") and (dc.creator all "Franz Kafka")
# Retrieved 183 main records for Das Urteil
# Fetching 91 related records for Das Urteil
# Retrieved 25 related records for Das Urteil
# Progress saved: 3127 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Augsburger Kreidekreis (Bertolt Brecht)
# Trying query: (dc.title all "Der Augsburger Kreidekreis") and (dc.creator all "Bertolt Brecht")
#  → Retrieved 6 records (start=1)
# Found 6 records for query: (dc.title all "Der Augsburger Kreidekreis") and (dc.creator all "Bertolt Brecht")
# Retrieved 6 main records for Der Augsburger Kreidekreis
# Fetching 0 related records for Der Augsburger Kreidekreis
# Retrieved 0 related records for Der Augsburger Kreidekreis
# Progress saved: 3133 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Besuch der alten Dame (Friedrich Dürrenmatt)
# Trying query: (dc.title all "Der Besuch der alten Dame") and (dc.creator all "Friedrich Dürrenmatt")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 3 records (start=76)
# Found 78 records for query: (dc.title all "Der Besuch der alten Dame") and (dc.creator all "Friedrich Dürrenmatt")
# Retrieved 78 main records for Der Besuch der alten Dame
# Fetching 8 related records for Der Besuch der alten Dame
# Retrieved 6 related records for Der Besuch der alten Dame
# Progress saved: 3214 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der blonde Eckbert (Ludwig Tieck)
# Trying query: (dc.title all "Der blonde Eckbert") and (dc.creator all "Ludwig Tieck")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 4 records (start=76)
# Found 79 records for query: (dc.title all "Der blonde Eckbert") and (dc.creator all "Ludwig Tieck")
# Retrieved 79 main records for Der blonde Eckbert
# Fetching 11 related records for Der blonde Eckbert
# Retrieved 6 related records for Der blonde Eckbert
# Progress saved: 3293 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der ewige Spießer (Ödön Horváth)
# Trying query: (dc.title all "Der ewige Spießer") and (dc.creator all "Ödön Horváth")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 10 records (start=51)
# Found 60 records for query: (dc.title all "Der ewige Spießer") and (dc.creator all "Ödön Horváth")
# Retrieved 60 main records for Der ewige Spießer
# Fetching 81 related records for Der ewige Spießer
# Retrieved 12 related records for Der ewige Spießer
# Progress saved: 3354 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Findling (Heinrich Kleist)
# Trying query: (dc.title all "Der Findling") and (dc.creator all "Heinrich Kleist")
#  → Retrieved 25 records (start=1)
#  → Retrieved 17 records (start=26)
# Found 42 records for query: (dc.title all "Der Findling") and (dc.creator all "Heinrich Kleist")
# Retrieved 42 main records for Der Findling
# Fetching 5 related records for Der Findling
# Retrieved 7 related records for Der Findling
# Progress saved: 3397 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der goldne Topf  (E.T.A. Hoffmann)
# Trying query: (dc.title all "Der goldne Topf ") and (dc.creator all "E.T.A. Hoffmann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 22 records (start=101)
# Found 122 records for query: (dc.title all "Der goldne Topf ") and (dc.creator all "E.T.A. Hoffmann")
# Retrieved 122 main records for Der goldne Topf
# Fetching 68 related records for Der goldne Topf
# Retrieved 18 related records for Der goldne Topf
# Progress saved: 3521 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der gute Gott von Manhattan (Ingeborg Bachmann)
# Trying query: (dc.title all "Der gute Gott von Manhattan") and (dc.creator all "Ingeborg Bachmann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 2 records (start=26)
# Found 27 records for query: (dc.title all "Der gute Gott von Manhattan") and (dc.creator all "Ingeborg Bachmann")
# Retrieved 27 main records for Der gute Gott von Manhattan
# Fetching 4 related records for Der gute Gott von Manhattan
# Retrieved 2 related records for Der gute Gott von Manhattan
# Progress saved: 3548 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der gute Mensch von Sezuan (Bertolt Brecht)
# Trying query: (dc.title all "Der gute Mensch von Sezuan") and (dc.creator all "Bertolt Brecht")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 24 records (start=76)
# Found 99 records for query: (dc.title all "Der gute Mensch von Sezuan") and (dc.creator all "Bertolt Brecht")
# Retrieved 99 main records for Der gute Mensch von Sezuan
# Fetching 9 related records for Der gute Mensch von Sezuan
# Retrieved 6 related records for Der gute Mensch von Sezuan
# Progress saved: 3648 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Hessische Landbote (Georg, Friedrich Ludwig Büchner, Weidig)
# Trying query: (dc.title all "Der Hessische Landbote") and (dc.creator all "Georg, Friedrich Ludwig Büchner, Weidig")
#  → Retrieved 2 records (start=1)
# Found 2 records for query: (dc.title all "Der Hessische Landbote") and (dc.creator all "Georg, Friedrich Ludwig Büchner, Weidig")
# Retrieved 2 main records for Der Hessische Landbote
# Fetching 0 related records for Der Hessische Landbote
# Retrieved 0 related records for Der Hessische Landbote
# Progress saved: 3650 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Hofmeister (Jakob Michael Reinhold Lenz)
# Trying query: (dc.title all "Der Hofmeister") and (dc.creator all "Jakob Michael Reinhold Lenz")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 17 records (start=51)
# Found 67 records for query: (dc.title all "Der Hofmeister") and (dc.creator all "Jakob Michael Reinhold Lenz")
# Retrieved 67 main records for Der Hofmeister
# Fetching 11 related records for Der Hofmeister
# Retrieved 9 related records for Der Hofmeister
# Progress saved: 3717 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Philister vor, in und nach der Geschichte (Clemens Brentano)
# Trying query: (dc.title all "Der Philister vor, in und nach der Geschichte") and (dc.creator all "Clemens Brentano")
#  → Retrieved 2 records (start=1)
# Found 2 records for query: (dc.title all "Der Philister vor, in und nach der Geschichte") and (dc.creator all "Clemens Brentano")
# Retrieved 2 main records for Der Philister vor, in und nach der Geschichte
# Fetching 0 related records for Der Philister vor, in und nach der Geschichte
# Retrieved 0 related records for Der Philister vor, in und nach der Geschichte
# Progress saved: 3719 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Process (Franz Kafka)
# Trying query: (dc.title all "Der Process") and (dc.creator all "Franz Kafka")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 7 records (start=76)
# Found 82 records for query: (dc.title all "Der Process") and (dc.creator all "Franz Kafka")
# Retrieved 82 main records for Der Process
# Fetching 35 related records for Der Process
# Retrieved 10 related records for Der Process
# Progress saved: 3793 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Russe ist einer, der Birken liebt (Olga Grjasnowa)
# Trying query: (dc.title all "Der Russe ist einer, der Birken liebt") and (dc.creator all "Olga Grjasnowa")
#  → Retrieved 20 records (start=1)
# Found 20 records for query: (dc.title all "Der Russe ist einer, der Birken liebt") and (dc.creator all "Olga Grjasnowa")
# Retrieved 20 main records for Der Russe ist einer, der Birken liebt
# Fetching 5 related records for Der Russe ist einer, der Birken liebt
# Retrieved 2 related records for Der Russe ist einer, der Birken liebt
# Progress saved: 3813 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Sandmann (E.T.A. Hoffmann)
# Trying query: (dc.title all "Der Sandmann") and (dc.creator all "E.T.A. Hoffmann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 20 records (start=176)
# Found 195 records for query: (dc.title all "Der Sandmann") and (dc.creator all "E.T.A. Hoffmann")
# Retrieved 195 main records for Der Sandmann
# Fetching 89 related records for Der Sandmann
# Retrieved 28 related records for Der Sandmann
# Progress saved: 4005 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Sonntag, an dem ich Weltmeister wurde (Friedrich Christian Delius)
# Trying query: (dc.title all "Der Sonntag, an dem ich Weltmeister wurde") and (dc.creator all "Friedrich Christian Delius")
#  → Retrieved 13 records (start=1)
# Found 13 records for query: (dc.title all "Der Sonntag, an dem ich Weltmeister wurde") and (dc.creator all "Friedrich Christian Delius")
# Retrieved 13 main records for Der Sonntag, an dem ich Weltmeister wurde
# Fetching 5 related records for Der Sonntag, an dem ich Weltmeister wurde
# Retrieved 2 related records for Der Sonntag, an dem ich Weltmeister wurde
# Progress saved: 4018 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Spinnerin Nachtlied (Clemens Brentano)
# Trying query: (dc.title all "Der Spinnerin Nachtlied") and (dc.creator all "Clemens Brentano")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Der Spinnerin Nachtlied") and (dc.creator all "Clemens Brentano")
# Trying query: (dc.title all "Der Spinnerin Nachtlied")
#  → Retrieved 5 records (start=1)
# Found 5 records for query: (dc.title all "Der Spinnerin Nachtlied")
# Retrieved 5 main records for Der Spinnerin Nachtlied
# Fetching 2 related records for Der Spinnerin Nachtlied
# Retrieved 0 related records for Der Spinnerin Nachtlied
# Progress saved: 4023 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Steppenwolf (Hermann Hesse)
# Trying query: (dc.title all "Der Steppenwolf") and (dc.creator all "Hermann Hesse")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 25 records (start=301)
#  → Retrieved 9 records (start=326)
# Found 334 records for query: (dc.title all "Der Steppenwolf") and (dc.creator all "Hermann Hesse")
# Retrieved 334 main records for Der Steppenwolf
# Fetching 10 related records for Der Steppenwolf
# Retrieved 6 related records for Der Steppenwolf
# Progress saved: 4355 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Trafikant (Robert Seethaler)
# Trying query: (dc.title all "Der Trafikant") and (dc.creator all "Robert Seethaler")
#  → Retrieved 25 records (start=1)
#  → Retrieved 5 records (start=26)
# Found 30 records for query: (dc.title all "Der Trafikant") and (dc.creator all "Robert Seethaler")
# Retrieved 30 main records for Der Trafikant
# Fetching 7 related records for Der Trafikant
# Retrieved 2 related records for Der Trafikant
# Progress saved: 4386 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Untertan (Heinrich Mann)
# Trying query: (dc.title all "Der Untertan") and (dc.creator all "Heinrich Mann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 16 records (start=251)
# Found 266 records for query: (dc.title all "Der Untertan") and (dc.creator all "Heinrich Mann")
# Retrieved 266 main records for Der Untertan
# Fetching 105 related records for Der Untertan
# Retrieved 63 related records for Der Untertan
# Progress saved: 4654 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Verbrecher aus verlorener Ehre (Friedrich Schiller)
# Trying query: (dc.title all "Der Verbrecher aus verlorener Ehre") and (dc.creator all "Friedrich Schiller")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 14 records (start=76)
# Found 89 records for query: (dc.title all "Der Verbrecher aus verlorener Ehre") and (dc.creator all "Friedrich Schiller")
# Retrieved 89 main records for Der Verbrecher aus verlorener Ehre
# Fetching 24 related records for Der Verbrecher aus verlorener Ehre
# Retrieved 17 related records for Der Verbrecher aus verlorener Ehre
# Progress saved: 4743 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Verlorene (Hans-Ulrich Treichel)
# Trying query: (dc.title all "Der Verlorene") and (dc.creator all "Hans-Ulrich Treichel")
#  → Retrieved 25 records (start=1)
#  → Retrieved 15 records (start=26)
# Found 40 records for query: (dc.title all "Der Verlorene") and (dc.creator all "Hans-Ulrich Treichel")
# Retrieved 40 main records for Der Verlorene
# Fetching 3 related records for Der Verlorene
# Retrieved 1 related records for Der Verlorene
# Progress saved: 4782 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Verschollene (Franz Kafka)
# Trying query: (dc.title all "Der Verschollene") and (dc.creator all "Franz Kafka")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 12 records (start=126)
# Found 137 records for query: (dc.title all "Der Verschollene") and (dc.creator all "Franz Kafka")
# Retrieved 137 main records for Der Verschollene
# Fetching 86 related records for Der Verschollene
# Retrieved 21 related records for Der Verschollene
# Progress saved: 4909 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Vorleser (Bernhard Schlink)
# Trying query: (dc.title all "Der Vorleser") and (dc.creator all "Bernhard Schlink")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 5 records (start=126)
# Found 130 records for query: (dc.title all "Der Vorleser") and (dc.creator all "Bernhard Schlink")
# Retrieved 130 main records for Der Vorleser
# Fetching 13 related records for Der Vorleser
# Retrieved 4 related records for Der Vorleser
# Progress saved: 5039 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der Zauberlehrling (Johann Wolfgang Goethe)
# Trying query: (dc.title all "Der Zauberlehrling") and (dc.creator all "Johann Wolfgang Goethe")
#  → Retrieved 25 records (start=1)
#  → Retrieved 12 records (start=26)
# Found 37 records for query: (dc.title all "Der Zauberlehrling") and (dc.creator all "Johann Wolfgang Goethe")
# Retrieved 37 main records for Der Zauberlehrling
# Fetching 7 related records for Der Zauberlehrling
# Retrieved 6 related records for Der Zauberlehrling
# Progress saved: 5077 total records in 251014_dnb_results.csv
#
# Fetching main records for: Der zerbrochne Krug (Heinrich Kleist)
# Trying query: (dc.title all "Der zerbrochne Krug") and (dc.creator all "Heinrich Kleist")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
# Found 100 records for query: (dc.title all "Der zerbrochne Krug") and (dc.creator all "Heinrich Kleist")
# Retrieved 100 main records for Der zerbrochne Krug
# Fetching 26 related records for Der zerbrochne Krug
# Retrieved 12 related records for Der zerbrochne Krug
# Progress saved: 5179 total records in 251014_dnb_results.csv
#
# Fetching main records for: Deutschland. Ein Wintermärchen (Heinrich Heine)
# Trying query: (dc.title all "Deutschland. Ein Wintermärchen") and (dc.creator all "Heinrich Heine")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 24 records (start=251)
# Found 274 records for query: (dc.title all "Deutschland. Ein Wintermärchen") and (dc.creator all "Heinrich Heine")
# Retrieved 274 main records for Deutschland. Ein Wintermärchen
# Fetching 45 related records for Deutschland. Ein Wintermärchen
# Retrieved 34 related records for Deutschland. Ein Wintermärchen
# Progress saved: 5454 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Berliner Antigone (Rolf Hochhuth)
# Trying query: (dc.title all "Die Berliner Antigone") and (dc.creator all "Rolf Hochhuth")
#  → Retrieved 19 records (start=1)
# Found 19 records for query: (dc.title all "Die Berliner Antigone") and (dc.creator all "Rolf Hochhuth")
# Retrieved 19 main records for Die Berliner Antigone
# Fetching 2 related records for Die Berliner Antigone
# Retrieved 2 related records for Die Berliner Antigone
# Progress saved: 5473 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Blechtrommel (Günter Grass)
# Trying query: (dc.title all "Die Blechtrommel") and (dc.creator all "Günter Grass")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 7 records (start=201)
# Found 207 records for query: (dc.title all "Die Blechtrommel") and (dc.creator all "Günter Grass")
# Retrieved 207 main records for Die Blechtrommel
# Fetching 9 related records for Die Blechtrommel
# Retrieved 6 related records for Die Blechtrommel
# Progress saved: 5681 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Dreigroschenoper (Bertolt Brecht)
# Trying query: (dc.title all "Die Dreigroschenoper") and (dc.creator all "Bertolt Brecht")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 9 records (start=126)
# Found 134 records for query: (dc.title all "Die Dreigroschenoper") and (dc.creator all "Bertolt Brecht")
# Retrieved 134 main records for Die Dreigroschenoper
# Fetching 13 related records for Die Dreigroschenoper
# Retrieved 6 related records for Die Dreigroschenoper
# Progress saved: 5814 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Furcht vor der Freiheit (Erich Fromm)
# Trying query: (dc.title all "Die Furcht vor der Freiheit") and (dc.creator all "Erich Fromm")
#  → Retrieved 25 records (start=1)
#  → Retrieved 3 records (start=26)
# Found 28 records for query: (dc.title all "Die Furcht vor der Freiheit") and (dc.creator all "Erich Fromm")
# Retrieved 28 main records for Die Furcht vor der Freiheit
# Fetching 5 related records for Die Furcht vor der Freiheit
# Retrieved 5 related records for Die Furcht vor der Freiheit
# Progress saved: 5842 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die heilige Johanna der Schlachthöfe (Bertolt Brecht)
# Trying query: (dc.title all "Die heilige Johanna der Schlachthöfe") and (dc.creator all "Bertolt Brecht")
#  → Retrieved 25 records (start=1)
#  → Retrieved 18 records (start=26)
# Found 43 records for query: (dc.title all "Die heilige Johanna der Schlachthöfe") and (dc.creator all "Bertolt Brecht")
# Retrieved 43 main records for Die heilige Johanna der Schlachthöfe
# Fetching 9 related records for Die heilige Johanna der Schlachthöfe
# Retrieved 2 related records for Die heilige Johanna der Schlachthöfe
# Progress saved: 5884 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Horen (Friedrich Schiller)
# Trying query: (dc.title all "Die Horen") and (dc.creator all "Friedrich Schiller")
#  → Retrieved 4 records (start=1)
# Found 4 records for query: (dc.title all "Die Horen") and (dc.creator all "Friedrich Schiller")
# Retrieved 4 main records for Die Horen
# Fetching 0 related records for Die Horen
# Retrieved 0 related records for Die Horen
# Progress saved: 5888 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Jahre der Liebe (Paul Nizon)
# Trying query: (dc.title all "Die Jahre der Liebe") and (dc.creator all "Paul Nizon")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Die Jahre der Liebe") and (dc.creator all "Paul Nizon")
# Trying query: (dc.title all "Die Jahre der Liebe")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 20 records (start=51)
# Found 70 records for query: (dc.title all "Die Jahre der Liebe")
# Retrieved 70 main records for Die Jahre der Liebe
# Fetching 26 related records for Die Jahre der Liebe
# Retrieved 14 related records for Die Jahre der Liebe
# Progress saved: 5962 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Judenbuche (Annette Droste-Hülshoff)
# Trying query: (dc.title all "Die Judenbuche") and (dc.creator all "Annette Droste-Hülshoff")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 25 records (start=301)
#  → Retrieved 22 records (start=326)
# Found 347 records for query: (dc.title all "Die Judenbuche") and (dc.creator all "Annette Droste-Hülshoff")
# Retrieved 347 main records for Die Judenbuche
# Fetching 97 related records for Die Judenbuche
# Retrieved 72 related records for Die Judenbuche
# Progress saved: 6309 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Jungfrau von Orleans (Friedrich Schiller)
# Trying query: (dc.title all "Die Jungfrau von Orleans") and (dc.creator all "Friedrich Schiller")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 10 records (start=151)
# Found 160 records for query: (dc.title all "Die Jungfrau von Orleans") and (dc.creator all "Friedrich Schiller")
# Retrieved 160 main records for Die Jungfrau von Orleans
# Fetching 46 related records for Die Jungfrau von Orleans
# Retrieved 24 related records for Die Jungfrau von Orleans
# Progress saved: 6471 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Kindermörderin (Heinrich Leopold Wagner)
# Trying query: (dc.title all "Die Kindermörderin") and (dc.creator all "Heinrich Leopold Wagner")
#  → Retrieved 25 records (start=1)
#  → Retrieved 13 records (start=26)
# Found 38 records for query: (dc.title all "Die Kindermörderin") and (dc.creator all "Heinrich Leopold Wagner")
# Retrieved 38 main records for Die Kindermörderin
# Fetching 5 related records for Die Kindermörderin
# Retrieved 3 related records for Die Kindermörderin
# Progress saved: 6509 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Leiden des jungen Werthers (Johann Wolfgang Goethe)
# Trying query: (dc.title all "Die Leiden des jungen Werthers") and (dc.creator all "Johann Wolfgang Goethe")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 25 records (start=301)
#  → Retrieved 25 records (start=326)
#  → Retrieved 25 records (start=351)
#  → Retrieved 25 records (start=376)
#  → Retrieved 25 records (start=401)
#  → Retrieved 25 records (start=426)
#  → Retrieved 25 records (start=451)
#  → Retrieved 25 records (start=476)
#  → Retrieved 25 records (start=501)
#  → Retrieved 6 records (start=526)
# Found 531 records for query: (dc.title all "Die Leiden des jungen Werthers") and (dc.creator all "Johann Wolfgang Goethe")
# Retrieved 531 main records for Die Leiden des jungen Werthers
# Fetching 62 related records for Die Leiden des jungen Werthers
# Retrieved 42 related records for Die Leiden des jungen Werthers
# Progress saved: 7043 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die letzten Tage der Menschheit (Karl Kraus)
# Trying query: (dc.title all "Die letzten Tage der Menschheit") and (dc.creator all "Karl Kraus")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 6 records (start=51)
# Found 56 records for query: (dc.title all "Die letzten Tage der Menschheit") and (dc.creator all "Karl Kraus")
# Retrieved 56 main records for Die letzten Tage der Menschheit
# Fetching 7 related records for Die letzten Tage der Menschheit
# Retrieved 2 related records for Die letzten Tage der Menschheit
# Progress saved: 7100 total records in 251014_dnb_results.csv
#
# Fetching main records for: Die Marquise von O. (Heinrich Kleist)
# Trying query: (dc.title all "Die Marquise von O.") and (dc.creator all "Heinrich Kleist")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 5 records (start=201)
# Found 205 records for query: (dc.title all "Die Marquise von O.") and (dc.creator all "Heinrich Kleist")
# ...
# Retrieved 0 related records for Schlechte Zeiten für Lyrik
# Progress saved: 29710 total records in 251014_dnb_results.csv
#
# Fetching main records for: Seeschlacht (Reinhard Goering)
# Trying query: (dc.title all "Seeschlacht") and (dc.creator all "Reinhard Goering")
#  → Retrieved 12 records (start=1)
# Found 12 records for query: (dc.title all "Seeschlacht") and (dc.creator all "Reinhard Goering")
# Retrieved 12 main records for Seeschlacht
# Fetching 0 related records for Seeschlacht
# Retrieved 0 related records for Seeschlacht
# Progress saved: 29722 total records in 251014_dnb_results.csv
#
# Fetching main records for: Sommerhaus, später (Judith Hermann)
# Trying query: (dc.title all "Sommerhaus, später") and (dc.creator all "Judith Hermann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 24 records (start=26)
# Found 49 records for query: (dc.title all "Sommerhaus, später") and (dc.creator all "Judith Hermann")
# Retrieved 49 main records for Sommerhaus, später
# Fetching 10 related records for Sommerhaus, später
# Retrieved 2 related records for Sommerhaus, später
# Progress saved: 29770 total records in 251014_dnb_results.csv
#
# Fetching main records for: Sprachgitter (Paul Celan)
# Trying query: (dc.title all "Sprachgitter") and (dc.creator all "Paul Celan")
#  → Retrieved 24 records (start=1)
# Found 24 records for query: (dc.title all "Sprachgitter") and (dc.creator all "Paul Celan")
# Retrieved 24 main records for Sprachgitter
# Fetching 0 related records for Sprachgitter
# Retrieved 0 related records for Sprachgitter
# Progress saved: 29794 total records in 251014_dnb_results.csv
#
# Fetching main records for: Tauben fliegen auf (Melinda Nadj Abonji)
# Trying query: (dc.title all "Tauben fliegen auf") and (dc.creator all "Melinda Nadj Abonji")
#  → Retrieved 23 records (start=1)
# Found 23 records for query: (dc.title all "Tauben fliegen auf") and (dc.creator all "Melinda Nadj Abonji")
# Retrieved 23 main records for Tauben fliegen auf
# Fetching 4 related records for Tauben fliegen auf
# Retrieved 2 related records for Tauben fliegen auf
# Progress saved: 29817 total records in 251014_dnb_results.csv
#
# Fetching main records for: Tauben im Gras (Wolfgang Koeppen)
# Trying query: (dc.title all "Tauben im Gras") and (dc.creator all "Wolfgang Koeppen")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 6 records (start=51)
# Found 56 records for query: (dc.title all "Tauben im Gras") and (dc.creator all "Wolfgang Koeppen")
# Retrieved 56 main records for Tauben im Gras
# Fetching 12 related records for Tauben im Gras
# Retrieved 2 related records for Tauben im Gras
# Progress saved: 29873 total records in 251014_dnb_results.csv
#
# Fetching main records for: Terror (Ferdinand von Schirach)
# Trying query: (dc.title all "Terror") and (dc.creator all "Ferdinand von Schirach")
#  → Retrieved 22 records (start=1)
# Found 22 records for query: (dc.title all "Terror") and (dc.creator all "Ferdinand von Schirach")
# Retrieved 22 main records for Terror
# Fetching 20 related records for Terror
# Retrieved 5 related records for Terror
# Progress saved: 29896 total records in 251014_dnb_results.csv
#
# Fetching main records for: Tod in Venedig (Thomas Mann)
# Trying query: (dc.title all "Tod in Venedig") and (dc.creator all "Thomas Mann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 25 records (start=276)
#  → Retrieved 1 records (start=301)
# Found 301 records for query: (dc.title all "Tod in Venedig") and (dc.creator all "Thomas Mann")
# Retrieved 301 main records for Tod in Venedig
# Fetching 31 related records for Tod in Venedig
# Retrieved 12 related records for Tod in Venedig
# Progress saved: 30176 total records in 251014_dnb_results.csv
#
# Fetching main records for: Tonio Kröger (Thomas Mann)
# Trying query: (dc.title all "Tonio Kröger") and (dc.creator all "Thomas Mann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 18 records (start=201)
# Found 218 records for query: (dc.title all "Tonio Kröger") and (dc.creator all "Thomas Mann")
# Retrieved 218 main records for Tonio Kröger
# Fetching 40 related records for Tonio Kröger
# Retrieved 28 related records for Tonio Kröger
# Progress saved: 30336 total records in 251014_dnb_results.csv
#
# Fetching main records for: Top Dogs (Urs Widmer)
# Trying query: (dc.title all "Top Dogs") and (dc.creator all "Urs Widmer")
#  → Retrieved 8 records (start=1)
# Found 8 records for query: (dc.title all "Top Dogs") and (dc.creator all "Urs Widmer")
# Retrieved 8 main records for Top Dogs
# Fetching 0 related records for Top Dogs
# Retrieved 0 related records for Top Dogs
# Progress saved: 30344 total records in 251014_dnb_results.csv
#
# Fetching main records for: Transit (Anna Seghers)
# Trying query: (dc.title all "Transit") and (dc.creator all "Anna Seghers")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 7 records (start=101)
# Found 107 records for query: (dc.title all "Transit") and (dc.creator all "Anna Seghers")
# Retrieved 107 main records for Transit
# Fetching 26 related records for Transit
# Retrieved 18 related records for Transit
# Progress saved: 30451 total records in 251014_dnb_results.csv
#
# Fetching main records for: Über das Marionettentheater (Heinrich Kleist)
# Trying query: (dc.title all "Über das Marionettentheater") and (dc.creator all "Heinrich Kleist")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 19 records (start=76)
# Found 94 records for query: (dc.title all "Über das Marionettentheater") and (dc.creator all "Heinrich Kleist")
# Retrieved 94 main records for Über das Marionettentheater
# Fetching 10 related records for Über das Marionettentheater
# Retrieved 9 related records for Über das Marionettentheater
# Progress saved: 30537 total records in 251014_dnb_results.csv
#
# Fetching main records for: Über die ästetische Erziehung der Menschen in einer Reihe von Briefen (Friedrich Schiller)
# Trying query: (dc.title all "Über die ästetische Erziehung der Menschen in einer Reihe von Briefen") and (dc.creator all "Friedrich Schiller")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Über die ästetische Erziehung der Menschen in einer Reihe von Briefen") and (dc.creator all "Friedrich Schiller")
# Trying query: (dc.title all "Über die ästetische Erziehung der Menschen in einer Reihe von Briefen")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Über die ästetische Erziehung der Menschen in einer Reihe von Briefen")
# Retrieved 0 main records for Über die ästetische Erziehung der Menschen in einer Reihe von Briefen
# Fetching 0 related records for Über die ästetische Erziehung der Menschen in einer Reihe von Briefen
# Retrieved 0 related records for Über die ästetische Erziehung der Menschen in einer Reihe von Briefen
# No records found for Über die ästetische Erziehung der Menschen in einer Reihe von Briefen
#
# Fetching main records for: Über die Bezeichnung Emigranten (Bertolt Brecht)
# Trying query: (dc.title all "Über die Bezeichnung Emigranten") and (dc.creator all "Bertolt Brecht")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Über die Bezeichnung Emigranten") and (dc.creator all "Bertolt Brecht")
# Trying query: (dc.title all "Über die Bezeichnung Emigranten")
#  → Retrieved 2 records (start=1)
# Found 2 records for query: (dc.title all "Über die Bezeichnung Emigranten")
# Retrieved 2 main records for Über die Bezeichnung Emigranten
# Fetching 2 related records for Über die Bezeichnung Emigranten
# Retrieved 0 related records for Über die Bezeichnung Emigranten
# Progress saved: 30539 total records in 251014_dnb_results.csv
#
# Fetching main records for: Under der linden (Walther von der Vogelweide)
# Trying query: (dc.title all "Under der linden") and (dc.creator all "Walther von der Vogelweide")
#  → Retrieved 2 records (start=1)
# Found 2 records for query: (dc.title all "Under der linden") and (dc.creator all "Walther von der Vogelweide")
# Retrieved 2 main records for Under der linden
# Fetching 0 related records for Under der linden
# Retrieved 0 related records for Under der linden
# Progress saved: 30541 total records in 251014_dnb_results.csv
#
# Fetching main records for: Undine (Friedrich de la Motte Fouqué)
# Trying query: (dc.title all "Undine") and (dc.creator all "Friedrich de la Motte Fouqué")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 10 records (start=151)
# Found 160 records for query: (dc.title all "Undine") and (dc.creator all "Friedrich de la Motte Fouqué")
# Retrieved 160 main records for Undine
# Fetching 29 related records for Undine
# Retrieved 20 related records for Undine
# Progress saved: 30702 total records in 251014_dnb_results.csv
#
# Fetching main records for: Unter der Drachenwand (Arno Geiger)
# Trying query: (dc.title all "Unter der Drachenwand") and (dc.creator all "Arno Geiger")
#  → Retrieved 23 records (start=1)
# Found 23 records for query: (dc.title all "Unter der Drachenwand") and (dc.creator all "Arno Geiger")
# Retrieved 23 main records for Unter der Drachenwand
# Fetching 12 related records for Unter der Drachenwand
# Retrieved 2 related records for Unter der Drachenwand
# Progress saved: 30723 total records in 251014_dnb_results.csv
#
# Fetching main records for: Verbrechen (Ferdinand Schirach)
# Trying query: (dc.title all "Verbrechen") and (dc.creator all "Ferdinand Schirach")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 12 records (start=51)
# Found 62 records for query: (dc.title all "Verbrechen") and (dc.creator all "Ferdinand Schirach")
# Retrieved 62 main records for Verbrechen
# Fetching 17 related records for Verbrechen
# Retrieved 2 related records for Verbrechen
# Progress saved: 30785 total records in 251014_dnb_results.csv
#
# Fetching main records for: Von deutscher Baukunst (Johann Wolfgang Goethe)
# Trying query: (dc.title all "Von deutscher Baukunst") and (dc.creator all "Johann Wolfgang Goethe")
#  → Retrieved 18 records (start=1)
# Found 18 records for query: (dc.title all "Von deutscher Baukunst") and (dc.creator all "Johann Wolfgang Goethe")
# Retrieved 18 main records for Von deutscher Baukunst
# Fetching 0 related records for Von deutscher Baukunst
# Retrieved 0 related records for Von deutscher Baukunst
# Progress saved: 30803 total records in 251014_dnb_results.csv
#
# Fetching main records for: Von morgens bis mitternachts (Georg Kaiser)
# Trying query: (dc.title all "Von morgens bis mitternachts") and (dc.creator all "Georg Kaiser")
#  → Retrieved 25 records (start=1)
#  → Retrieved 10 records (start=26)
# Found 35 records for query: (dc.title all "Von morgens bis mitternachts") and (dc.creator all "Georg Kaiser")
# Retrieved 35 main records for Von morgens bis mitternachts
# Fetching 6 related records for Von morgens bis mitternachts
# Retrieved 3 related records for Von morgens bis mitternachts
# Progress saved: 30838 total records in 251014_dnb_results.csv
#
# Fetching main records for: Vor dem Fest (Saša Staniši?)
# Trying query: (dc.title all "Vor dem Fest") and (dc.creator all "Saša Staniši?")
#  → Retrieved 25 records (start=1)
#  → Retrieved 4 records (start=26)
# Found 29 records for query: (dc.title all "Vor dem Fest") and (dc.creator all "Saša Staniši?")
# Retrieved 29 main records for Vor dem Fest
# Fetching 8 related records for Vor dem Fest
# Retrieved 4 related records for Vor dem Fest
# Progress saved: 30866 total records in 251014_dnb_results.csv
#
# Fetching main records for: Vor Sonnenaufgang (Gerhart Hauptmann)
# Trying query: (dc.title all "Vor Sonnenaufgang") and (dc.creator all "Gerhart Hauptmann")
#  → Retrieved 25 records (start=1)
#  → Retrieved 21 records (start=26)
# Found 46 records for query: (dc.title all "Vor Sonnenaufgang") and (dc.creator all "Gerhart Hauptmann")
# Retrieved 46 main records for Vor Sonnenaufgang
# Fetching 11 related records for Vor Sonnenaufgang
# Retrieved 8 related records for Vor Sonnenaufgang
# Progress saved: 30912 total records in 251014_dnb_results.csv
#
# Fetching main records for: Weh dem, der aus der Reihe tanzt (Ludwig Harig)
# Trying query: (dc.title all "Weh dem, der aus der Reihe tanzt") and (dc.creator all "Ludwig Harig")
#  → Retrieved 9 records (start=1)
# Found 9 records for query: (dc.title all "Weh dem, der aus der Reihe tanzt") and (dc.creator all "Ludwig Harig")
# Retrieved 9 main records for Weh dem, der aus der Reihe tanzt
# Fetching 0 related records for Weh dem, der aus der Reihe tanzt
# Retrieved 0 related records for Weh dem, der aus der Reihe tanzt
# Progress saved: 30921 total records in 251014_dnb_results.csv
#
# Fetching main records for: Woyzeck (Georg Büchner)
# Trying query: (dc.title all "Woyzeck") and (dc.creator all "Georg Büchner")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 24 records (start=201)
# Found 224 records for query: (dc.title all "Woyzeck") and (dc.creator all "Georg Büchner")
# Retrieved 224 main records for Woyzeck
# Fetching 38 related records for Woyzeck
# Retrieved 16 related records for Woyzeck
# Progress saved: 31065 total records in 251014_dnb_results.csv
#
# Fetching main records for: Wünschelrute (Joseph Eichendorff)
# Trying query: (dc.title all "Wünschelrute") and (dc.creator all "Joseph Eichendorff")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Wünschelrute") and (dc.creator all "Joseph Eichendorff")
# Trying query: (dc.title all "Wünschelrute")
#  → Retrieved 25 records (start=1)
#  → Retrieved 25 records (start=26)
#  → Retrieved 25 records (start=51)
#  → Retrieved 25 records (start=76)
#  → Retrieved 25 records (start=101)
#  → Retrieved 25 records (start=126)
#  → Retrieved 25 records (start=151)
#  → Retrieved 25 records (start=176)
#  → Retrieved 25 records (start=201)
#  → Retrieved 25 records (start=226)
#  → Retrieved 25 records (start=251)
#  → Retrieved 21 records (start=276)
# Found 296 records for query: (dc.title all "Wünschelrute")
# Retrieved 296 main records for Wünschelrute
# Fetching 41 related records for Wünschelrute
# Retrieved 29 related records for Wünschelrute
# Progress saved: 31361 total records in 251014_dnb_results.csv
#
# Fetching main records for: Zehn (Franka Potente)
# Trying query: (dc.title all "Zehn") and (dc.creator all "Franka Potente")
#  → Retrieved 3 records (start=1)
# Found 3 records for query: (dc.title all "Zehn") and (dc.creator all "Franka Potente")
# Retrieved 3 main records for Zehn
# Fetching 0 related records for Zehn
# Retrieved 0 related records for Zehn
# Progress saved: 31364 total records in 251014_dnb_results.csv
#
# Fetching main records for: Ziehende Landschaft (Hilde Domin)
# Trying query: (dc.title all "Ziehende Landschaft") and (dc.creator all "Hilde Domin")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Ziehende Landschaft") and (dc.creator all "Hilde Domin")
# Trying query: (dc.title all "Ziehende Landschaft")
#  → Retrieved 0 records (start=1)
# No results for query: (dc.title all "Ziehende Landschaft")
# Retrieved 0 main records for Ziehende Landschaft
# Fetching 0 related records for Ziehende Landschaft
# Retrieved 0 related records for Ziehende Landschaft
# No records found for Ziehende Landschaft
# Script finished safely.
